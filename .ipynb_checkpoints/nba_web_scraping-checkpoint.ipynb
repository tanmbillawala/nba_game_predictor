# %% [markdown]
# ## Python package for nba data: https://pypi.org/project/nba_api/
# Documentation: https://github.com/swar/nba_api/blob/master/docs/table_of_contents.md
#
# Sample code is below:

# %%
# to install the package, uncomment line below
#! pip install nba_api

# %%
from nba_api.stats.static import teams

nba_teams = teams.get_teams()
# Select the dictionary for the Celtics, which contains their team ID
celtics = [team for team in nba_teams if team['abbreviation'] == 'BOS'][0]
celtics_id = celtics['id']

# %%
from nba_api.stats.endpoints import teamgamelogs

# Query for games where the Celtics were playing
celticlog = teamgamelogs.TeamGameLogs(team_id_nullable=celtics_id)
# The first DataFrame of those returned is what we want.
games = celticlog.get_data_frames()[0]
games.head()
# Out:
#   SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 0     2016-17  1610612738               BOS  Boston Celtics  0021601219
# 1     2016-17  1610612738               BOS  Boston Celtics  0021601204
# 2     2016-17  1610612738               BOS  Boston Celtics  0021601189
# 3     2016-17  1610612738               BOS  Boston Celtics  0021601177
# 4     2016-17  1610612738               BOS  Boston Celtics  0021601169
#
#              GAME_DATE      MATCHUP WL   MIN  FGM  ...  AST_RANK  TOV_RANK  \
# 0  2017-04-12T00:00:00  BOS vs. MIL  W  48.0   41  ...         8         5
# 1  2017-04-10T00:00:00  BOS vs. BKN  W  48.0   41  ...         8        47
# 2  2017-04-08T00:00:00    BOS @ CHA  W  48.0   45  ...         3         9
# 3  2017-04-06T00:00:00    BOS @ ATL  L  48.0   37  ...        18        26
# 4  2017-04-05T00:00:00  BOS vs. CLE  L  48.0   33  ...        64        37
#
#    STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# ...
